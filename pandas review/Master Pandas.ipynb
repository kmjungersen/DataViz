# %% [markdown]
# ## Importing necessary libraries

# %%
import pandas as pd

# %% [markdown]
# The cell below adjusts notebook settings.  These commands make the notebook wider and utilizes more space on the screen.

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container {width:90% !important;}</style>"))
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 10)
# Out:
# <style>.container {width:90% !important;}</style>

# %% [markdown]
# ## Loading data

# %%
data = pd.read_csv('happiness_with_continent.csv')

# %% [markdown]
# The cell above loads comma-separated-values, there are other load functions: go to (https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html)
# <img src="read_functions.jpg"
#      alt="missing data" height = "800" width = "800"
#      align = "midel" />

# %%
data.shape  #RETURNS THE DIMENSIONS OF THE DATAFRAME (ROWS, COLUMNS)
# Out:
# (1704, 27)

# %%
data.head(10)
# Out:
#   Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008     3.723590            7.168690        0.450662
# 1  Afghanistan  2009     4.401778            7.333790        0.552308
# 2  Afghanistan  2010     4.758381            7.386629        0.539075
# 3  Afghanistan  2011     3.831719            7.415019        0.521104
# 4  Afghanistan  2012     3.782938            7.517126        0.520637
# 5  Afghanistan  2013     3.572100            7.522238        0.483552
# 6  Afghanistan  2014     3.130896            7.516955        0.525568
# 7  Afghanistan  2015     3.982855            7.500539        0.528597
# 8  Afghanistan  2016     4.220169            7.497038        0.559072
# 9  Afghanistan  2017     2.661718            7.497755        0.490880
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         50.799999                      0.718114    0.177889
# ...

# %%
data2=pd.read_csv('TRUST.csv')

# %%
data2.shape
# Out:
# (216, 28)

# %%
data2.head(25)
# Out:
#     ROW_UNO  TRAN_UNO  TRUST_UNO TRAN_TYPE                TRAN_DATE  PERIOD  \
# 0      1256      1256         45        CR  2012-12-31 00:00:00.000  201212
# 1      1257      1257         45        CR  2012-12-31 00:00:00.000  201212
# 2      1258      1258         45        CR  2013-01-01 00:00:00.000  201301
# 3      1259      1259         45        CR  2013-01-01 00:00:00.000  201301
# 4      1260      1260         45        CR  2013-01-01 00:00:00.000  201301
# ..      ...       ...        ...       ...                      ...     ...
# 20     1276      1276         45        CR  2013-08-30 00:00:00.000  201308
# 21     1277      1277         45        CR  2013-09-09 00:00:00.000  201309
# 22     1278      1278         45       TRA  2013-09-16 00:00:00.000  201309
# 23     1279      1279         45        CR  2013-09-30 00:00:00.000  201309
# 24     1280      1280         45        CR  2013-09-30 00:00:00.000  201309
#
# ...

# %%
data2.columns
# Out:
# Index(['ROW_UNO', 'TRAN_UNO', 'TRUST_UNO', 'TRAN_TYPE', 'TRAN_DATE', 'PERIOD',
#        'GL_AUDIT_NUM', 'SIGN', 'AMOUNT_TYPE', 'AMOUNT', 'HOLD_DATE', 'REMARKS',
#        'HELD', 'DRUNO', 'BAL_ZERO_NO_FCA', 'TRX_TYPE_CODE', 'WITHHOLD_TAX',
#        'REF_NUMBER', 'MATURITY_DATE', 'AUTH_UNO', 'INT_CLEAR_DAYS',
#        'ADJ_TRAN_DATE', 'TC_AMOUNT', 'TC_CODE', 'BANKREC_DTX_UNO', 'SESSION',
#        'EI_ID', 'LAST_MODIFIED'],
#       dtype='object')

# %%
data2.describe()
# Out:
#         ROW_UNO  TRAN_UNO  TRUST_UNO         PERIOD  GL_AUDIT_NUM        SIGN  \
# count   216.000   216.000      216.0     216.000000    216.000000  216.000000
# mean   1363.500  1363.500       45.0  201561.611111 -11315.694444    0.962963
# std      62.498    62.498        0.0     173.686263   8625.155066    0.270260
# min    1256.000  1256.000       45.0  201212.000000 -27588.000000   -1.000000
# 25%    1309.750  1309.750       45.0  201407.000000 -18486.000000    1.000000
# 50%    1363.500  1363.500       45.0  201603.000000 -10503.000000    1.000000
# 75%    1417.250  1417.250       45.0  201707.000000  -3275.750000    1.000000
# max    1471.000  1471.000       45.0  201901.000000      0.000000    1.000000
#
#               AMOUNT  HOLD_DATE  DRUNO  BAL_ZERO_NO_FCA  WITHHOLD_TAX  \
# count     216.000000        0.0  216.0              0.0           0.0
# mean     3150.045880        NaN    1.0              NaN           NaN
# ...

# %%
import numpy as np

# %%
df = data2

# %%
df.head(10)
# Out:
#    ROW_UNO  TRAN_UNO  TRUST_UNO TRAN_TYPE                TRAN_DATE  PERIOD  \
# 0     1256      1256         45        CR  2012-12-31 00:00:00.000  201212
# 1     1257      1257         45        CR  2012-12-31 00:00:00.000  201212
# 2     1258      1258         45        CR  2013-01-01 00:00:00.000  201301
# 3     1259      1259         45        CR  2013-01-01 00:00:00.000  201301
# 4     1260      1260         45        CR  2013-01-01 00:00:00.000  201301
# 5     1261      1261         45        CR  2013-01-31 00:00:00.000  201301
# 6     1262      1262         45        CR  2013-02-28 00:00:00.000  201302
# 7     1263      1263         45        CR  2013-03-29 00:00:00.000  201303
# 8     1264      1264         45       TRA  2013-03-29 00:00:00.000  201303
# 9     1265      1265         45        CR  2013-04-01 00:00:00.000  201304
#
#    GL_AUDIT_NUM  SIGN AMOUNT_TYPE     AMOUNT  HOLD_DATE  \
# 0          -324     1           P  100000.00        NaN
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

fig, ax = plt.subplots()
ax.plot(df.filter(['TRAN_UNO']), df.filter(['AMOUNT']))

# formatter = ticker.FormatStrFormatter('$1.2f')
# ax.yaxis.set_major_formatter(formatter)

plt.show()

# %%
df.plot.line()

# %% [markdown]
# ### Inspecting the data

# %%
data.columns #RETURNS A LIST OF ALL COLUMN NAMES IN THE DATAFRAME
# Out:
# Index(['Country name', 'Year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect',
#        'Confidence in national government', 'Democratic Quality',
#        'Delivery Quality', 'Standard deviation of ladder by country-year',
#        'Standard deviation/Mean of ladder by country-year',
#        'GINI index (World Bank estimate)',
#        'GINI index (World Bank estimate), average 2000-16',
#        'gini of household income reported in Gallup, by wp5-year',
#        'Most people can be trusted, Gallup',
#        'Most people can be trusted, WVS round 1981-1984',
#        'Most people can be trusted, WVS round 1989-1993',
#        'Most people can be trusted, WVS round 1994-1998',
#        'Most people can be trusted, WVS round 1999-2004',
#        'Most people can be trusted, WVS round 2005-2009',
# ...

# %%
data.index  #RETURNS THE 'INTERNAL' ROW NAMES/NUMBERS OF THE DATAFRAME
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
data.info() #THIS GIVES US INFORMATION ABOUT THE COLUMN DATA:  THE 'TYPE' AND THE PRESENCE/ABSENCE OF 'NULL-VALUES'
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 27 columns):
# Country name                                                1704 non-null object
# Year                                                        1704 non-null int64
# Life Ladder                                                 1704 non-null float64
# Log GDP per capita                                          1676 non-null float64
# Social support                                              1691 non-null float64
# Healthy life expectancy at birth                            1676 non-null float64
# Freedom to make life choices                                1675 non-null float64
# Generosity                                                  1622 non-null float64
# Perceptions of corruption                                   1608 non-null float64
# Positive affect                                             1685 non-null float64
# ...

# %%
data2.info()

# %%
data.describe() #THIS RETURNS DESCRIPTIVE STATISTICAL INFORMATION ABOUT THE NUMERICAL VARIABLES IN THE DATAFRAME

# %%
data.describe().index

# %% [markdown]
# ### Sorting the data

# %%
data.sort_values() #THIS WON'T WORK (it will throw an error) BECAUSE WE NEED TO TELL PANDAS WHICH VARIABLE TO USE FOR THE SORT.

# %%
data.sort_values(by='Year').head(5) #THIS SORTS BY YEAR.  THE DEFAULT IS ASCENDING:  (ascending=True)

# %%
data.sort_values(by=['Country name','Year']).head(5)

# %%
data.sort_values(by=['Country name','Year'], ascending=[False,True]).head(5)

# %%
data.sort_index(ascending=False).head(5)

# %% [markdown]
# ### Filtering the data

# %%
data.Year.head(5)

# %%
data['Year'].head(5) #THIS IS PREFERABLE TO THE PREVIOUS COMMAND, ALTHOUGH THEY PRODUCE THE SAME RESULTS.  WHY IS THIS PREFERABLE?  TRY TO EXECUTE THE NEXT COMMAND

# %%
data['Country name','Life Ladder']

# %%
data
data[['Country name','Life Ladder']]

# %% [markdown]
# syntax of `iloc` is `data.iloc[start_row:end_row (,start_col:end_coll)]`

# %%
data.iloc[10]

# %%
data.iloc[10,3]

# %%
data.iloc[903:907]

# %%
data.iloc[903:907,0:3]

# %%
data.set_index('Country name',inplace=True)

# %%
data.sample(5)

# %%
data.index

# %% [markdown]
# Syntax for `loc`: `data.loc[index_label (,col_label)]`

# %%
data.loc['United States']

# %%
data.loc['United States','Life Ladder']

# %%
data.loc['Denmark':'Germany', ['Year','Life Ladder']].sample(5)

# %% [markdown]
# ### Filtering on boolean values

# %%
from numpy.random import randint
index = ['A','B','A','D']

df = pd.DataFrame(
    index = index,
    data = {
    'values':randint(10,size=len(index))
})
print('DataFrame:')
print(df)

overlay = pd.Series(
    index=index,
    data=[True,False,True,False]
)
print('\nOverlay:')
print(overlay)

print('\nMasked DataFrame:')
print(df.loc[overlay])

# %%
# Option 1
data.loc[data['Life Ladder']  > 4]

# Alternative
condition = data['Life Ladder']  > 4
data.loc[condition]

# %%
life_condition = data['Life Ladder']  > 4
year_condition = data['Year']  > 2014
gen_condition = data['Generosity'] > .2

data.loc[life_condition & year_condition & gen_condition]

# %%
data.reset_index()

# %%
cond_year = data['Year'].apply(lambda x: x%3 == 0)
cond_america = data['Continent'].apply(lambda x: 'America' in x)

data[cond_year & cond_america]

# %%
data.min()

# %%
data.sum()

# %%
data.mean()

# %%
data.median()

# %%
data.quantile(q=.8)

# %%
data.iloc[:,:-1].idxmax()

# %%
data['Year'] / data['Life Ladder']

# %%
data['Continent'] + '_' + data['Year'].astype(str)

# %%
data.head()

# %%
data.std()

# %%
def above_1000_below_10(x):
    try:
        pd.to_numeric(x)
    except:
        return 'no number column'
    
    if x > 1000:
        return 'above_1000'
    elif x < 10:
        return 'below_10'
    else:
        return 'mid'

# %%
data['Year'].apply(above_1000_below_10)

# %%
data['Continent'].apply(lambda x: x.split(' ')[-1])

# %%
def country_before_2015(df):
    if df['Year'] < 2015:
        return df.name
    else:
        return df['Continent']
    
data.apply(country_before_2015,axis=1)

# %%
data.apply(country_before_2015,axis=1)

# %%
data.groupby(['Year','Continent'])['Life Ladder'].idxmax()

# %%
def get_random_country(group):
    return np.random.choice(group.index.values)

data.groupby(['Year','Continent']).apply(get_random_country)

# %%
data.groupby(['Year','Continent']).apply(
  lambda group: np.random.choice(group['Life Ladder'])
)

# %%
data.groupby(['Country name'])['Life Ladder'].transform(np.median)

# %%
data.groupby(['Country name'])['Life Ladder'].transform(np.median) \
- data['Life Ladder']
