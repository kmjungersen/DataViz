# %% [markdown]
# from Python Pandas - Visualization (https://www.tutorialspoint.com/python_pandas/python_pandas_visualization.htm)

# %% [markdown]
# ## Import

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.DataFrame(np.random.randn(10,4),index=pd.date_range('1/1/2000',
   periods=10), columns=list('ABCD'))

# %%
df1.shape
# Out:
# (10, 4)

# %%
df1.head(10)
# Out:
#                    A         B         C         D
# 2000-01-01 -2.223637  0.531089  0.229779 -1.264908
# 2000-01-02  0.402375  0.633060 -0.822518 -1.711698
# 2000-01-03 -1.042883 -2.219965  1.526353  1.997449
# 2000-01-04 -0.550673 -0.055376 -1.505712  0.951739
# 2000-01-05 -2.976367 -0.809538 -1.828611 -1.022907
# 2000-01-06  1.398375 -1.381737 -1.654952  0.200107
# 2000-01-07  0.792597 -0.005100  1.001547 -0.800489
# 2000-01-08  0.839240 -0.004821  0.535779 -1.669505
# 2000-01-09  0.164673 -1.161965  1.429498  1.213948
# 2000-01-10 -0.521348  0.367009  0.552435 -0.812811

# %% [markdown]
# ## Line Charts and Bar Charts

# %%
df1.plot()

# %%
df2 = pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked=True)

# %%
df2.plot.barh(stacked=True)

# %% [markdown]
# ## Histograms

# %%
df3 = pd.DataFrame({'a':np.random.randn(1000)+1,'b':np.random.randn(1000),'c':
np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])

# %%
df3.plot.hist(bins=100)

# %%
df3.hist(bins=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CA155F2808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CA16BF5488>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001CA16C65C08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001CA16CB8D48>]],
#       dtype=object)

# %% [markdown]
# ## Box Plots

# %%
df5 = pd.DataFrame(np.random.rand(10, 5), columns=['A', 'B', 'C', 'D', 'E'])

# %%
df5.plot.box()

# %% [markdown]
# If you've never seen "box and whisker" plots, see (https://en.wikipedia.org/wiki/Box_plot)

# %% [markdown]
# ## Area Plots

# %%
df5 = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])

# %%
df5.plot.area()

# %% [markdown]
# ## Scatter Plots

# %%
df6 = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])

# %%
df6.plot.scatter(x='a', y='b')

# %% [markdown]
# ## Pie Chart
# "The only thing worse than a pie chart is several of them." - Edward Tufte

# %%
df7 = pd.DataFrame(3 * np.random.rand(4), index=['a', 'b', 'c', 'd'], columns=['x'])

# %%
df7.plot.pie(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001CA17269648>],
#       dtype=object)
